# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import folium

# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
applications = pd.read_csv('../data/pruned_data.csv', low_memory=False)
applications
# Out:
#           Unnamed: 0                   lei  derived_msa_md state_code  \
# 0                  0  RVDPPPGHCGZ40J4VQ731           26420         TX
# 1                  1  RVDPPPGHCGZ40J4VQ731           19124         TX
# 2                  2  RVDPPPGHCGZ40J4VQ731           40900         CA
# 3                  3  RVDPPPGHCGZ40J4VQ731           25540         CT
# 4                  4  RVDPPPGHCGZ40J4VQ731           12580         MD
# ...              ...                   ...             ...        ...
# 12974034    16080204  RVDPPPGHCGZ40J4VQ731           38060         AZ
# 12974035    16080205  RVDPPPGHCGZ40J4VQ731           12060         GA
# 12974036    16080206  RVDPPPGHCGZ40J4VQ731           29820         NV
# 12974037    16080207  RVDPPPGHCGZ40J4VQ731           39340         UT
# 12974038    16080208  RVDPPPGHCGZ40J4VQ731           29820         NV
#
#           census_tract conforming_loan_limit derived_loan_product_type  \
# ...

# %%
applications['census_string'] = [str(tract)[:-2] for tract in applications['census_tract']]
applications['census_string'] = ['0'+ tract if len(tract) == 10 else tract for tract in applications['census_string']]
applications.head()
# Out:
#    Unnamed: 0                   lei  derived_msa_md state_code  census_tract  \
# 0           0  RVDPPPGHCGZ40J4VQ731           26420         TX  4.820155e+10
# 1           1  RVDPPPGHCGZ40J4VQ731           19124         TX  4.808503e+10
# 2           2  RVDPPPGHCGZ40J4VQ731           40900         CA  6.017030e+09
# 3           3  RVDPPPGHCGZ40J4VQ731           25540         CT  9.013538e+09
# 4           4  RVDPPPGHCGZ40J4VQ731           12580         MD  2.451015e+10
#
#   conforming_loan_limit derived_loan_product_type  \
# 0                     C   Conventional:First Lien
# 1                     C            FHA:First Lien
# 2                     C   Conventional:First Lien
# 3                     C            FHA:First Lien
# 4                     C            FHA:First Lien
#
#               derived_dwelling_category        derived_ethnicity  \
# 0  Single Family (1-4 Units):Site-Built   Not Hispanic or Latino
# 1  Single Family (1-4 Units):Site-Built   Not Hispanic or Latino
# ...

# %%
applications.groupby('census_string')['lei'].nunique().sort_values().reset_index()
# Out:
#       census_string   lei
# 0       66010953200     1
# 1       42101980001     1
# 2       56021980801     1
# 3       42101980300     1
# 4       06065940100     1
# ...             ...   ...
# 83912   48473680100   272
# 83913   48201542902   279
# 83914   48085030307   284
# 83915   48157673202   308
# 83916             n  1095
#
# [83917 rows x 2 columns]

# %%
len(applications[applications['census_string'] == '48157673202']['lei'].unique())
# Out:
# 308

# %%
inst_count = applications[applications['census_string'] != 'n'].groupby('census_string')['lei'].nunique().reset_index()
inst_count
# Out:
#       census_string  lei
# 0       01001020100   41
# 1       01001020200   27
# 2       01001020300   46
# 3       01001020400   53
# 4       01001020501   55
# ...             ...  ...
# 83911   78030960200    2
# 83912   78030960400    1
# 83913   78030960700    1
# 83914   78030961100    1
# 83915   78030961200    1
#
# [83916 rows x 2 columns]
